# %%
import pandas as pd
# import numpy as np
df = pd.read_csv("https://goo.gl/iDUKrL")
song_list = list(df.reset_index().T.to_dict().values())
len(song_list)
# Out:
# 100

# %%
# pd.read_excel("...", sheet_name='현황')  # 암호화된 파일은 기본에서는 미지원

# %%
df = pd.read_csv("https://goo.gl/iDUKrL", index_col='곡일련번호')  # pd.DataFrame
print(df.shape)
df.head()
# Out:
# (100, 6)
#           순위                        앨범                                    곡명  \
# 곡일련번호
# 31346009   1                        삐삐                                    삐삐
# 31344113   2                   시간이 들겠지                 시간이 들겠지 (Feat. Colde)
# 31340985   3       쇼미더머니 777 Episode 1  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)
# 31316695   4    하루도 그대를 사랑하지 않은 적이 없었다                하루도 그대를 사랑하지 않은 적이 없었다
# 31266290   5  LOVE YOURSELF 結 `Answer`                                  IDOL
#
#              가수                                           커버이미지_주소     좋아요
# 곡일련번호
# 31346009    아이유  https://cdnimg.melon.co.kr/cm/album/images/102...   61528
# 31344113     로꼬  https://cdnimg.melon.co.kr/cm/album/images/102...   48331
# 31340985   pH-1  https://cdnimg.melon.co.kr/cm/album/images/102...   54022
# 31316695    임창정  https://cdnimg.melon.co.kr/cm/album/images/102...   97984
# 31266290  방탄소년단  https://cdnimg.melon.co.kr/cm/album/images/101...  173279

# %%
df.columns
# Out:
# Index(['순위', '앨범', '곡명', '가수', '커버이미지_주소', '좋아요'], dtype='object')

# %%
song_list = list(df.reset_index().T.to_dict().values())

# %%
# 형식 지정자

print("안녕하세요. 저는 %s입니다." % "이진석")
print("안녕하세요. 저는 {}입니다.".format("이진석"))
print("안녕하세요. 저는 {name}입니다.".format(name="이진석"))
# Out:
# 안녕하세요. 저는 이진석입니다.
# 안녕하세요. 저는 이진석입니다.
# 안녕하세요. 저는 이진석입니다.

# %%
def 월급_계산(기본급, 야근시간):
    return 기본급 + 야근시간 * 10000

# %%
print(월급_계산(1000000, 20))
print(월급_계산(20, 1000000))

print(월급_계산(기본급=1000000, 야근시간=20))
print(월급_계산(야근시간=20, 기본급=1000000))
# Out:
# 1200000
# 10000000020
# 1200000
# 1200000

# %%
# 위치 인자 (Positional Arguments)에서의 unpacking
mylist = [1000000, 20]
print(월급_계산(mylist[0], mylist[1]))
print(월급_계산(*mylist))
# Out:
# 1200000
# 1200000

# %%
# 키워드 인자 (Keyword Arguments)에서의 unpacking
mydict = {'기본급': 1000000, '야근시간': 20}
print(월급_계산(mydict['기본급'], mydict['야근시간']))  # 위치인자
print(월급_계산(기본급=mydict['기본급'], 야근시간=mydict['야근시간']))
print(월급_계산(**mydict))
# Out:
# 1200000
# 1200000
# 1200000

# %%
print("1")
print("1", "2")
print("1", "2", "3")
# Out:
# 1
# 1 2
# 1 2 3

# %%
# 가변인자
def myprint(*args, **kwargs):  # packing
    print(f"args : {args}")
    print(f"kwargs : {kwargs}")

# %%
myprint(1, 2, 3)
# Out:
# args : (1, 2, 3)
# kwargs : {}

# %%
myprint(a='1', b=2)
# Out:
# args : ()
# kwargs : {'a': '1', 'b': 2}

# %%
myprint(1, 2, 3, c=4)
# Out:
# args : (1, 2, 3)
# kwargs : {'c': 4}

# %%
# 반환값 (return value)
#  - 파이썬은 무조건 반환값이 1개입니다.
def mycalc(x, y):
    x * 10 + y

print(mycalc(1, 2))
# Out:
# None

# %%
def 부가세_계산(결제금액):
    부가세 = 결제금액 // 11
    부가세_뺀_금액 = 결제금액 - 부가세
    return 부가세_뺀_금액, 부가세

부가세_계산(20000)
# Out:
# (18182, 1818)

# %%
금액1, 금액2 = 부가세_계산(20000)

# %%
x, y = 1, 2

# %%
def 월급_계산2(기본급, 야근시간=0):
    return 기본급 + 야근시간 * 10000

월급_계산2(1000000)
# Out:
# 1000000

# %% [markdown]
# # 디폴트 인자에는 절대 muttable값을 넣으시면 안 됩니다.
#
# + immutable : str, int, tuple, None

# %%
def 좋아하는_메뉴(메뉴, 메뉴_리스트=[]):
    메뉴_리스트.append(메뉴)
    return 메뉴_리스트

# %%
좋아하는_메뉴("김밥")
# Out:
# ['김밥']

# %%
좋아하는_메뉴("커피")
# Out:
# ['김밥', '커피']

# %%
def 좋아하는_메뉴2(메뉴, 메뉴_리스트=None):
    if 메뉴_리스트 is None:
        메뉴_리스트 = []
    메뉴_리스트.append(메뉴)
    return 메뉴_리스트

print(좋아하는_메뉴2("김밥"))
print(좋아하는_메뉴2("라면"))
# Out:
# ['김밥']
# ['라면']

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers._make_parser_function.<locals>.parser_f(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)>

# %% [markdown]
# # Pandas

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')  # 윈도우: Malgun Gothic
rc('axes', unicode_minus=False)

import pandas as pd
import numpy as np

# %%
# range(0, 10, 1)  # 정수 범위
array_x = np.arange(0, 20, 0.01)  # ndarray
len(array_x)
# Out:
# 2000

# %%
array_y = np.sin(array_x)

# %%
plt.plot(array_x, array_y)

# %% [markdown]
# ## 1차원 데이터

# %%
data = ["사과", "바나나"]
series1 = pd.Series(data)
series1
# Out:
# 0     사과
# 1    바나나
# dtype: object

# %%
series1
# Out:
# 0     사과
# 1    바나나
# dtype: object

# %%
data = {10: "사과", 11: "바나나", 10: "수박"}
pd.Series(data)
# Out:
# 10     수박
# 11    바나나
# dtype: object

# %%
data = ["사과", "바나나", "수박"]
series3 = pd.Series(data, index=[10, 11, 10])
series3
# Out:
# 10     사과
# 11    바나나
# 10     수박
# dtype: object

# %%
series3[10]
# Out:
# 10    사과
# 10    수박
# dtype: object

# %%
series3[11]
# Out:
# '바나나'

# %%
data = tuple({"사과", "바나나"})
pd.Series(data)
# Out:
# 0    바나나
# 1     사과
# dtype: object

# %% [markdown]
# ## 2차원 데이터

# %%
df = pd.DataFrame(song_list).set_index("곡일련번호")
print(df.shape)
df.head()
# Out:
# (100, 6)
#              가수                                    곡명  순위  \
# 곡일련번호
# 31346009    아이유                                    삐삐   1
# 31344113     로꼬                 시간이 들겠지 (Feat. Colde)   2
# 31340985   pH-1  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)   3
# 31316695    임창정                하루도 그대를 사랑하지 않은 적이 없었다   4
# 31266290  방탄소년단                                  IDOL   5
#
#                                 앨범     좋아요  \
# 곡일련번호
# 31346009                        삐삐   61528
# 31344113                   시간이 들겠지   48331
# 31340985       쇼미더머니 777 Episode 1   54022
# 31316695    하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290  LOVE YOURSELF 結 `Answer`  173279
#
#                                                    커버이미지_주소
# 곡일련번호
# 31346009  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31344113  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31340985  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31316695  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266290  https://cdnimg.melon.co.kr/cm/album/images/101...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 31346009 to 30806540
# Data columns (total 6 columns):
# 가수          100 non-null object
# 곡명          100 non-null object
# 순위          100 non-null int64
# 앨범          100 non-null object
# 좋아요         100 non-null int64
# 커버이미지_주소    100 non-null object
# dtypes: int64(2), object(4)
# memory usage: 5.5+ KB

# %%
df.describe()
# Out:
#                순위            좋아요
# count  100.000000     100.000000
# mean    50.500000  109429.060000
# std     29.011492   72060.919511
# min      1.000000    2508.000000
# 25%     25.750000   59995.000000
# 50%     50.500000   96877.500000
# 75%     75.250000  137529.250000
# max    100.000000  359130.000000

# %%
df.columns
# Out:
# Index(['가수', '곡명', '순위', '앨범', '좋아요', '커버이미지_주소'], dtype='object')

# %%
df['곡명']
# Out:
# 곡일련번호
# 31346009                                       삐삐
# 31344113                    시간이 들겠지 (Feat. Colde)
# 31340985     Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)
# 31316695                   하루도 그대를 사랑하지 않은 적이 없었다
# 31266290                                     IDOL
# 31331745                       이별길 (GOODBYE ROAD)
# 31340982                     사임사임 (Feat. CHANGMO)
# 31266289                                 I`m Fine
# 31314142                                  우리 그만하자
# 31085237                                FAKE LOVE
# 31314144                                  가을 타나 봐
# 31266282                                 Euphoria
# 31302310                                   헤어지는 중
# 31266291                     Answer : Love Myself
# 31085238             전하지 못한 진심 (Feat. Steve Aoki)
# 31266288                                 Epiphany
# 31266286                        Trivia 轉 : Seesaw
# 30962526    모든 날, 모든 순간 (Every day, Every Moment)
# 31280273                                    YOUNG
# 31266292                    Trivia 起 : Just Dance
# 31286161                              사이렌 (Siren)
# 31266300                          Trivia 承 : Love
# 31062863                                      열애중
# 31151836                            Way Back Home
# 31085244                                 Anpanman
# 30244931                                       봄날
# 30637982                                      DNA
# 31085243                            Airplane pt.2
# 30806536                                 Universe
# 31309079                                 We Young
#                             ...
# 31246870                                     한(一)
# 31035061                                      주지마
# 31147211                                   Dejavu
# 30849733                                      You
# 31340984                       패 (Feat. 넉살, 딥플로우)
# 31309947                                    도망가지마
# 30721801                                   My Way
# 30514366                                       선물
# 31227367                                     좋은 날
# 31113242                        영원+1 (Prod. NELL)
# 31266377                                    AND I
# 31331749                  I Don’t Care (with 스푼즈)
# 31147212                            북극성 (Polaris)
# 30970444                         소나기 (Feat. 10cm)
# 31113244                        11 (Prod. 다이나믹듀오)
# 4032981                                      여보세요
# 31299371                                    잘 지내요
# 30806539                    지나갈 테니 (Been Through)
# 31324696                                  Perfect
# 8111603                                  HandClap
# 30661885                             WHERE YOU AT
# 31006730                            What is Love?
# 31052421              밤 (Time for the moon night)
# 31194610                                   Love U
# 31147210                                   Signal
# 30937275                                 별이 빛나는 밤
# 31147213                                   ylenoL
# 31288765                         몰랐니 (Lil` Touch)
# 31147214                      중력달 (Gravity&Moon;)
# 30806540                                     Stay
# Name: 곡명, Length: 100, dtype: object

# %%
# name = ['곡명', '좋아요']
# df[name]

df[['좋아요', '가수', '곡명']]
# Out:
#              좋아요                     가수                                     곡명
# 곡일련번호
# 31346009   61528                    아이유                                     삐삐
# 31344113   48331                     로꼬                  시간이 들겠지 (Feat. Colde)
# 31340985   54022                   pH-1   Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)
# 31316695   97984                    임창정                 하루도 그대를 사랑하지 않은 적이 없었다
# 31266290  173279                  방탄소년단                                   IDOL
# 31331745   55396                   iKON                     이별길 (GOODBYE ROAD)
# 31340982   27564                 Coogie                   사임사임 (Feat. CHANGMO)
# 31266289  132847                  방탄소년단                               I`m Fine
# 31314142   95771                    로이킴                                우리 그만하자
# 31085237  253847                  방탄소년단                              FAKE LOVE
# 31314144   28056                    바이브                                가을 타나 봐
# 31266282  129017                  방탄소년단                               Euphoria
# 31302310   77050             펀치 (Punch)                                 헤어지는 중
# 31266291  108151                  방탄소년단                   Answer : Love Myself
# 31085238  176653                  방탄소년단           전하지 못한 진심 (Feat. Steve Aoki)
# 31266288  101011                  방탄소년단                               Epiphany
# 31266286   98436                  방탄소년단                      Trivia 轉 : Seesaw
# 30962526  185706                     폴킴  모든 날, 모든 순간 (Every day, Every Moment)
# 31280273   91106          백현 (BAEKHYUN)                                  YOUNG
# 31266292   88970                  방탄소년단                  Trivia 起 : Just Dance
# 31286161   91516                     선미                            사이렌 (Siren)
# 31266300   83610                  방탄소년단                        Trivia 承 : Love
# 31062863  115805                      벤                                    열애중
# 31151836  225308              숀 (SHAUN)                          Way Back Home
# 31085244  138694                  방탄소년단                               Anpanman
# 30244931  359130                  방탄소년단                                     봄날
# 30637982  323911                  방탄소년단                                    DNA
# 31085243  127355                  방탄소년단                          Airplane pt.2
# 30806536  155809                    EXO                               Universe
# 31309079   53852                     찬열                               We Young
# ...          ...                    ...                                    ...
# 31246870   69062                (여자)아이들                                   한(一)
# 31035061  154263                     로꼬                                    주지마
# 31147211   53081                 뉴이스트 W                                 Dejavu
# 30849733  141103                   멜로망스                                    You
# 31340984   10536                    김효은                     패 (Feat. 넉살, 딥플로우)
# 31309947   48716             모트 (Motte)                                  도망가지마
# 30721801  119657           이수 (엠씨 더 맥스)                                 My Way
# 30514366  266869                   멜로망스                                     선물
# 31227367   33146                   멜로망스                                   좋은 날
# 31113242   76313  Wanna One (워너원) - 린온미                      영원+1 (Prod. NELL)
# 31266377   20736                 뉴이스트 W                                  AND I
# 31331749   13544                 뉴이스트 W                I Don’t Care (with 스푼즈)
# 31147212   32098                 뉴이스트 W                          북극성 (Polaris)
# 30970444  130935                    용준형                       소나기 (Feat. 10cm)
# 31113244   67211  Wanna One (워너원) - 남바완                      11 (Prod. 다이나믹듀오)
# 4032981   126064                 NU`EST                                   여보세요
# 31299371   25169                    정승환                                  잘 지내요
# 30806539   88331                    EXO                  지나갈 테니 (Been Through)
# 31324696   24732                   10cm                                Perfect
# 8111603   156476    Fitz & The Tantrums                               HandClap
# 30661885   92753                 뉴이스트 W                           WHERE YOU AT
# 31006730  121530           TWICE (트와이스)                          What is Love?
# 31052421  125760         여자친구 (GFRIEND)            밤 (Time for the moon night)
# 31194610   61670                     청하                                 Love U
# 31147210   27270                 뉴이스트 W                                 Signal
# 30937275  145494           마마무(Mamamoo)                               별이 빛나는 밤
# 31147213   26136                 뉴이스트 W                                 ylenoL
# 31288765   42853             소녀시대-Oh!GG                       몰랐니 (Lil` Touch)
# 31147214   26091                 뉴이스트 W                    중력달 (Gravity&Moon;)
# 30806540   81556                    EXO                                   Stay
#
# [100 rows x 3 columns]

# %%
df['가수'].value_counts()  # 가수별 곡수
# Out:
# 방탄소년단                       14
# 뉴이스트 W                       8
# Wanna One (워너원)              5
# 멜로망스                         4
# EXO                          3
# iKON                         3
# 세븐틴                          2
# 10cm                         2
# 마마무(Mamamoo)                 2
# 폴킴                           2
# TWICE (트와이스)                 2
# 비투비                          2
# BLACKPINK                    2
# 로꼬                           2
# 로이킴                          2
# 바이브                          2
# 닐로 (Nilo)                    2
# 아이유                          2
# EXO-CBX (첸백시)                1
# 용준형                          1
# Wanna One (워너원) - 더힐         1
# 기리보이                         1
# 이수 (엠씨 더 맥스)                 1
# 임한별                          1
# Fitz & The Tantrums          1
# 박원                           1
# 양다일                          1
# 승리                           1
# (여자)아이들                      1
# 임창정                          1
# 볼빨간사춘기                       1
# nafla                        1
# 찬열                           1
# 레이 (LAY)                     1
# 모트 (Motte)                   1
# 지코 (ZICO)                    1
# Wanna One (워너원) - 린온미        1
# 저스디스 (JUSTHIS)               1
# 청하                           1
# 펀치 (Punch)                   1
# 선미                           1
# 김효은                          1
# pH-1                         1
# 여자친구 (GFRIEND)               1
# Wanna One (워너원) - 트리플포지션     1
# Wanna One (워너원) - 남바완        1
# 백현 (BAEKHYUN)                1
# Apink (에이핑크)                 1
# 소녀시대-Oh!GG                   1
# 장덕철                          1
# 숀 (SHAUN)                    1
# 정승환                          1
# NU`EST                       1
# 먼데이 키즈 (Monday Kiz)          1
# Red Velvet (레드벨벳)            1
# 벤                            1
# Coogie                       1
# Name: 가수, dtype: int64

# %%
가수별_곡수 = df['가수'].value_counts()
mask = 가수별_곡수 >= 3
가수별_곡수[mask]
# Out:
# 방탄소년단              14
# 뉴이스트 W              8
# Wanna One (워너원)     5
# 멜로망스                4
# EXO                 3
# iKON                3
# Name: 가수, dtype: int64

# %%
# 가수별_곡수[mask].plot.pie()  # bar, barh, pie()
가수별_곡수[mask].plot(kind='pie')

# %%
figure, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
figure.set_size_inches(10, 10)

가수별_곡수[mask].plot.bar(ax=ax1) 
가수별_곡수[mask].plot.barh(ax=ax2) 
가수별_곡수[mask].plot.pie(ax=ax3)

# %% [markdown]
# # seaborn을 통한 샘플 데이터 로딩
#
# + matplotlib보다 조금 더 이쁜 시각화 라이브러리

# %%
import seaborn as sns

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df[['sex', 'survived']].head()
# Out:
#       sex  survived
# 0    male         0
# 1  female         1
# 2  female         1
# 3  female         1
# 4    male         0

# %%
titanic_df['survived'].mean()  # 평균
# Out:
# 0.3838383838383838

# %%
tips_df = sns.load_dataset('tips')
print(tips_df.shape)
tips_df.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips_df.pivot_table(index='sex',
                    values=['tip', 'total_bill'], aggfunc='mean')  # min, max, sum, mean, median
# Out:
#              tip  total_bill
# sex
# Male    3.089618   20.744076
# Female  2.833448   18.056897

# %% [markdown]
# # 원하는 범위 지정하기

# %%
import seaborn as sns
titanic_df = sns.load_dataset('titanic')
print(titanic_df.shape)
titanic_df.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.head()  # .tail()
# titanic_df.iloc[:5]  # 의미상으로는 .head()와 동일
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic_df['fare'].head()  # 컬럼이 1개 => Series, 2개 이상 => DataFrame
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: fare, dtype: float64

# %%
titanic_df[['fare']].head()  # DataFrame
# Out:
#       fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
song_df = pd.DataFrame(song_list).set_index('곡일련번호')
print(song_df.shape)
song_df.head()
# Out:
# (100, 6)
#              가수                                    곡명  순위  \
# 곡일련번호
# 31346009    아이유                                    삐삐   1
# 31344113     로꼬                 시간이 들겠지 (Feat. Colde)   2
# 31340985   pH-1  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)   3
# 31316695    임창정                하루도 그대를 사랑하지 않은 적이 없었다   4
# 31266290  방탄소년단                                  IDOL   5
#
#                                 앨범     좋아요  \
# 곡일련번호
# 31346009                        삐삐   61528
# 31344113                   시간이 들겠지   48331
# 31340985       쇼미더머니 777 Episode 1   54022
# 31316695    하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290  LOVE YOURSELF 結 `Answer`  173279
#
#                                                    커버이미지_주소
# 곡일련번호
# 31346009  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31344113  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31340985  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31316695  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266290  https://cdnimg.melon.co.kr/cm/album/images/101...

# %%
# song_df[['곡명', '좋아요']]
song_df.loc[[31344113, 31266290, 31316695]]  # 개별 index 지정
# Out:
#              가수                      곡명  순위                        앨범     좋아요  \
# 곡일련번호
# 31344113     로꼬   시간이 들겠지 (Feat. Colde)   2                   시간이 들겠지   48331
# 31266290  방탄소년단                    IDOL   5  LOVE YOURSELF 結 `Answer`  173279
# 31316695    임창정  하루도 그대를 사랑하지 않은 적이 없었다   4    하루도 그대를 사랑하지 않은 적이 없었다   97984
#
#                                                    커버이미지_주소
# 곡일련번호
# 31344113  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266290  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31316695  https://cdnimg.melon.co.kr/cm/album/images/102...

# %%
song_df.loc[31340985:31266290]
# Out:
#              가수                                    곡명  순위  \
# 곡일련번호
# 31340985   pH-1  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)   3
# 31316695    임창정                하루도 그대를 사랑하지 않은 적이 없었다   4
# 31266290  방탄소년단                                  IDOL   5
#
#                                 앨범     좋아요  \
# 곡일련번호
# 31340985       쇼미더머니 777 Episode 1   54022
# 31316695    하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290  LOVE YOURSELF 結 `Answer`  173279
#
#                                                    커버이미지_주소
# 곡일련번호
# 31340985  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31316695  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266290  https://cdnimg.melon.co.kr/cm/album/images/101...

# %%
song_df.loc[31340985:31266290][['곡명', '좋아요']]
# Out:
#                                             곡명     좋아요
# 곡일련번호
# 31340985  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)   54022
# 31316695                하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290                                  IDOL  173279

# %%
song_df.loc[31340985:31266290, ['곡명', '좋아요']]
# Out:
#                                             곡명     좋아요
# 곡일련번호
# 31340985  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)   54022
# 31316695                하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290                                  IDOL  173279

# %%
# song_df[['곡명', '좋아요']].head()
song_df.loc[:, ['곡명', '좋아요']].head()
# Out:
#                                             곡명     좋아요
# 곡일련번호
# 31346009                                    삐삐   61528
# 31344113                 시간이 들겠지 (Feat. Colde)   48331
# 31340985  Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)   54022
# 31316695                하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290                                  IDOL  173279

# %%
# mask = song_df['가수'] == '방탄소년단'  # Broadcast => Boolean Mask
# mask = song_df['좋아요'] >= 200_000
# mask = song_df['곡명'].str.contains('가을')

# mask = (song_df['가수'] == '방탄소년단') & (song_df['좋아요'] >= 200_000)

mask = song_df['가수'] == '방탄소년단'
mask &= song_df['좋아요'] >= 200_000

song_df.loc[mask]
# Out:
#              가수         곡명  순위                      앨범     좋아요  \
# 곡일련번호
# 31085237  방탄소년단  FAKE LOVE  10  LOVE YOURSELF 轉 `Tear`  253847
# 30244931  방탄소년단         봄날  26    YOU NEVER WALK ALONE  359130
# 30637982  방탄소년단        DNA  27   LOVE YOURSELF 承 `Her`  323911
#
#                                                    커버이미지_주소
# 곡일련번호
# 31085237  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30244931  https://cdnimg.melon.co.kr/cm/album/images/100...
# 30637982  https://cdnimg.melon.co.kr/cm/album/images/100...

# %%
for index, row in song_df.iterrows():
    if row['좋아요'] >= 200_000:
        print('{곡명} {좋아요}'.format(**row))
# Out:
# FAKE LOVE 253847
# Way Back Home 225308
# 봄날 359130
# DNA 323911
# 에너제틱 (Energetic) 268394
# 사랑을 했다 (LOVE SCENARIO) 267692
# Beautiful 216065
# 밤편지 283167
# 그날처럼 208427
# 그리워하다 203463
# 선물 266869

# %%
#### 실습 ####

# %%
song_df
# Out:
#                              가수                                     곡명   순위  \
# 곡일련번호
# 31346009                    아이유                                     삐삐    1
# 31344113                     로꼬                  시간이 들겠지 (Feat. Colde)    2
# 31340985                   pH-1   Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)    3
# 31316695                    임창정                 하루도 그대를 사랑하지 않은 적이 없었다    4
# 31266290                  방탄소년단                                   IDOL    5
# 31331745                   iKON                     이별길 (GOODBYE ROAD)    6
# 31340982                 Coogie                   사임사임 (Feat. CHANGMO)    7
# 31266289                  방탄소년단                               I`m Fine    8
# 31314142                    로이킴                                우리 그만하자    9
# 31085237                  방탄소년단                              FAKE LOVE   10
# 31314144                    바이브                                가을 타나 봐   11
# 31266282                  방탄소년단                               Euphoria   12
# 31302310             펀치 (Punch)                                 헤어지는 중   13
# 31266291                  방탄소년단                   Answer : Love Myself   14
# 31085238                  방탄소년단           전하지 못한 진심 (Feat. Steve Aoki)   15
# 31266288                  방탄소년단                               Epiphany   16
# 31266286                  방탄소년단                      Trivia 轉 : Seesaw   17
# 30962526                     폴킴  모든 날, 모든 순간 (Every day, Every Moment)   18
# 31280273          백현 (BAEKHYUN)                                  YOUNG   19
# 31266292                  방탄소년단                  Trivia 起 : Just Dance   20
# 31286161                     선미                            사이렌 (Siren)   21
# 31266300                  방탄소년단                        Trivia 承 : Love   22
# 31062863                      벤                                    열애중   23
# 31151836              숀 (SHAUN)                          Way Back Home   24
# 31085244                  방탄소년단                               Anpanman   25
# 30244931                  방탄소년단                                     봄날   26
# 30637982                  방탄소년단                                    DNA   27
# 31085243                  방탄소년단                          Airplane pt.2   28
# 30806536                    EXO                               Universe   29
# 31309079                     찬열                               We Young   30
# ...                         ...                                    ...  ...
# 31246870                (여자)아이들                                   한(一)   71
# 31035061                     로꼬                                    주지마   72
# 31147211                 뉴이스트 W                                 Dejavu   73
# 30849733                   멜로망스                                    You   74
# 31340984                    김효은                     패 (Feat. 넉살, 딥플로우)   75
# 31309947             모트 (Motte)                                  도망가지마   76
# 30721801           이수 (엠씨 더 맥스)                                 My Way   77
# 30514366                   멜로망스                                     선물   78
# 31227367                   멜로망스                                   좋은 날   79
# 31113242  Wanna One (워너원) - 린온미                      영원+1 (Prod. NELL)   80
# 31266377                 뉴이스트 W                                  AND I   81
# 31331749                 뉴이스트 W                I Don’t Care (with 스푼즈)   82
# 31147212                 뉴이스트 W                          북극성 (Polaris)   83
# 30970444                    용준형                       소나기 (Feat. 10cm)   84
# 31113244  Wanna One (워너원) - 남바완                      11 (Prod. 다이나믹듀오)   85
# 4032981                  NU`EST                                   여보세요   86
# 31299371                    정승환                                  잘 지내요   87
# 30806539                    EXO                  지나갈 테니 (Been Through)   88
# 31324696                   10cm                                Perfect   89
# 8111603     Fitz & The Tantrums                               HandClap   90
# 30661885                 뉴이스트 W                           WHERE YOU AT   91
# 31006730           TWICE (트와이스)                          What is Love?   92
# 31052421         여자친구 (GFRIEND)            밤 (Time for the moon night)   93
# 31194610                     청하                                 Love U   94
# 31147210                 뉴이스트 W                                 Signal   95
# 30937275           마마무(Mamamoo)                               별이 빛나는 밤   96
# 31147213                 뉴이스트 W                                 ylenoL   97
# 31288765             소녀시대-Oh!GG                       몰랐니 (Lil` Touch)   98
# 31147214                 뉴이스트 W                    중력달 (Gravity&Moon;)   99
# 30806540                    EXO                                   Stay  100
#
#                                                          앨범     좋아요  \
# 곡일련번호
# 31346009                                                 삐삐   61528
# 31344113                                            시간이 들겠지   48331
# 31340985                                쇼미더머니 777 Episode 1   54022
# 31316695                             하루도 그대를 사랑하지 않은 적이 없었다   97984
# 31266290                           LOVE YOURSELF 結 `Answer`  173279
# 31331745                               NEW KIDS : THE FINAL   55396
# 31340982                                쇼미더머니 777 Episode 1   27564
# 31266289                           LOVE YOURSELF 結 `Answer`  132847
# 31314142                                            우리 그만하자   95771
# 31085237                             LOVE YOURSELF 轉 `Tear`  253847
# 31314144                                            가을 타나 봐   28056
# 31266282                           LOVE YOURSELF 結 `Answer`  129017
# 31302310                                             헤어지는 중   77050
# 31266291                           LOVE YOURSELF 結 `Answer`  108151
# 31085238                             LOVE YOURSELF 轉 `Tear`  176653
# 31266288                           LOVE YOURSELF 結 `Answer`  101011
# 31266286                           LOVE YOURSELF 結 `Answer`   98436
# 30962526                            `키스 먼저 할까요?` OST Part.3  185706
# 31280273                                              YOUNG   91106
# 31266292                           LOVE YOURSELF 結 `Answer`   88970
# 31286161                                            WARNING   91516
# 31266300                           LOVE YOURSELF 結 `Answer`   83610
# 31062863                                             RECIPE  115805
# 31151836                                               Take  225308
# 31085244                             LOVE YOURSELF 轉 `Tear`  138694
# 30244931                               YOU NEVER WALK ALONE  359130
# 30637982                              LOVE YOURSELF 承 `Her`  323911
# 31085243                             LOVE YOURSELF 轉 `Tear`  127355
# 30806536                         Universe - 겨울 스페셜 앨범, 2017  155809
# 31309079                                           We Young   53852
# ...                                                     ...     ...
# 31246870                                               한(一)   69062
# 31035061                                  건반 위의 하이에나 Part.4  154263
# 31147211                                           WHO, YOU   53081
# 30849733                              투유 프로젝트 - 슈가맨2 Part.2  141103
# 31340984                                쇼미더머니 777 Episode 1   10536
# 31309947                                      A-TEEN Part.4   48716
# 30721801                                      돈꽃 OST Part.1  119657
# 30514366                                          Moonlight  266869
# 31227367                                 미스터 션샤인 OST Part.5   33146
# 31113242                                  1÷χ=1 (UNDIVIDED)   76313
# 31266377                                미스터 션샤인 OST Part.10   20736
# 31331749                            I Don’t Care (with 스푼즈)   13544
# 31147212                                           WHO, YOU   32098
# 30970444                                   소나기 (Feat. 10cm)  130935
# 31113244                                  1÷χ=1 (UNDIVIDED)   67211
# 4032981                        THE SECOND MINI ALBUM `여보세요`  126064
# 31299371                                     라이프 OST Part.6   25169
# 30806539                         Universe - 겨울 스페셜 앨범, 2017   88331
# 31324696                                   연애플레이리스트3 Part.1   24732
# 8111603                      Fitz and The Tantrums (Deluxe)  156476
# 30661885                                            W, HERE   92753
# 31006730                                      What is Love?  121530
# 31052421  여자친구 The 6th Mini Album 'Time for the moon night'  125760
# 31194610                                      Blooming Blue   61670
# 31147210                                           WHO, YOU   27270
# 30937275                                      Yellow Flower  145494
# 31147213                                           WHO, YOU   26136
# 31288765                         몰랐니 - The 1st Single Album   42853
# 31147214                                           WHO, YOU   26091
# 30806540                         Universe - 겨울 스페셜 앨범, 2017   81556
#
#                                                    커버이미지_주소
# 곡일련번호
# 31346009  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31344113  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31340985  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31316695  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266290  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31331745  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31340982  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266289  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31314142  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31085237  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31314144  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266282  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31302310  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266291  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31085238  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31266288  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31266286  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30962526  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31280273  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31266292  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31286161  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31266300  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31062863  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31151836  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31085244  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30244931  https://cdnimg.melon.co.kr/cm/album/images/100...
# 30637982  https://cdnimg.melon.co.kr/cm/album/images/100...
# 31085243  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30806536  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31309079  https://cdnimg.melon.co.kr/cm/album/images/102...
# ...                                                     ...
# 31246870  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31035061  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31147211  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30849733  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31340984  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31309947  https://cdnimg.melon.co.kr/cm/album/images/102...
# 30721801  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30514366  https://cdnimg.melon.co.kr/cm/album/images/100...
# 31227367  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31113242  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31266377  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31331749  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31147212  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30970444  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31113244  https://cdnimg.melon.co.kr/cm/album/images/101...
# 4032981   https://cdnimg.melon.co.kr/cm/album/images/021...
# 31299371  https://cdnimg.melon.co.kr/cm/album/images/102...
# 30806539  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31324696  https://cdnimg.melon.co.kr/cm/album/images/102...
# 8111603   https://cdnimg.melon.co.kr/cm/album/images/026...
# 30661885  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31006730  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31052421  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31194610  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31147210  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30937275  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31147213  https://cdnimg.melon.co.kr/cm/album/images/101...
# 31288765  https://cdnimg.melon.co.kr/cm/album/images/102...
# 31147214  https://cdnimg.melon.co.kr/cm/album/images/101...
# 30806540  https://cdnimg.melon.co.kr/cm/album/images/101...
#
# [100 rows x 6 columns]

# %%
song_df.pivot_table(index='가수',
                    values=['곡명', '좋아요'], aggfunc='sum').head()
# Out:
#                  좋아요
# 가수
# (여자)아이들        69062
# 10cm           87044
# Apink (에이핑크)   88037
# BLACKPINK     312253
# Coogie         27564

# %%
mask = song_df['곡명'].str.contains('사랑')

# %%
song_df.loc[mask]
# Out:
#             가수                      곡명  순위                      앨범     좋아요  \
# 곡일련번호
# 31316695   임창정  하루도 그대를 사랑하지 않은 적이 없었다   4  하루도 그대를 사랑하지 않은 적이 없었다   97984
# 30859584  iKON  사랑을 했다 (LOVE SCENARIO)  42                  Return  267692
#
#                                                    커버이미지_주소
# 곡일련번호
# 31316695  https://cdnimg.melon.co.kr/cm/album/images/102...
# 30859584  https://cdnimg.melon.co.kr/cm/album/images/101...

# %% [markdown]
# # 좋아요 200,000이 넘는 곡

# %%
for song in song_list:
    if song['좋아요'] >= 200000:
        print('{곡명} {좋아요}'.format(**song))

# %%
def check(song):
    return song['좋아요'] >= 200000

for song in filter(check, song_list):
    print('{곡명} {좋아요}'.format(**song))

# %%
import pandas as pd

song_df = pd.DataFrame(song_list)
mask = song_df['좋아요'] >= 200000
song_df.loc[mask]
