# %%
# 실습 190528

# %%
국어 = 100
영어 = 80
수학 = 95

# %%
총점 = 국어 + 영어 + 수학
평균 = 총점 / 3
총점, 평균
# Out:
# (275, 91.66666666666667)

# %%
print('총점 : %d, 평균 : %.2f' % (총점, 평균))   # 옛날 문법 스타일
# Out:
# 총점 : 275, 평균 : 91.67

# %%
print(f'총점 : {총점}, 평균 : {평균:.2f}')    # 요즘 스타일
# Out:
# 총점 : 275, 평균 : 91.67

# %%
국어 = int(input('국어 성적: '))
수학 = int(input('수학 성적: '))
영어 = int(input('영어 성적: '))
# Out:
# 국어 성적: 100
# 수학 성적: 90
# 영어 성적: 85

# %%
line = input('국어 수학 영어 성적 : ')
# 국어, 수학, 영어 = line.split()
try:
    국어, 수학, 영어 = map(int, line.split())
except ValueError:
    print('성적을 세개 적으시오~~')
# Out:
# 국어 수학 영어 성적 : 100 90
# 성적을 세개 적으시오~~

# %%
num = input('5digit num : ')
num
# Out:
# 5digit num : 12345
# '12345'

# %%
num[0], num[1], num[2], num[3], num[4]
# Out:
# ('1', '2', '3', '4', '5')

# %%
', '.join(num)
# Out:
# '1, 2, 3, 4, 5'

# %%
# 기본자료형

# %%
['a', 'b', 'c'] # list
{'a', 'b', 'c'} #set
('a', 'b', 'c') #tuple
'a', 'b', 'c'   #tuple
# Out:
# ('a', 'b', 'c')

# %%
[1]  # list
[1,] # list
(1)  # int
(1,) # tuple

# 만들어서 쓸때는 웬만하면 list로 만들어 써라, 오류안생기게
# 튜플은 받으면 쓰고
# Out:
# (1,)

# %%
# 빈거
# [], list()
# (), tuple()
# set()
# {}, dict{}

# %%
{'a', 'b'}  # set
{'a': 1, 'b': 2} #dict
# Out:
# {'a': 1, 'b': 2}

# %%
type(max(input('정수다섯개를 내놓아라')))
# Out:
# 정수다섯개를 내놓아라1 2 3 4 5
# str

# %%
maaax = max(int(input('정수다섯개를 내놓아라')))
print(f'가장큰값은 {maaax}')
# Out:
# 정수다섯개를 내놓아라2 3 4 5 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-72b2fde045a2> in <module>
# ----> 1 maaax = max(int(input('정수다섯개를 내놓아라')))
#       2 print(f'가장큰값은 {maaax}')
#
# ValueError: invalid literal for int() with base 10: '2 3 4 5 6'

# %%
max(map(int, split(input('5정수->'))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e85f01cf61c0> in <module>
# ----> 1 max(map(int, split(input('5정수->'))))
#
# NameError: name 'split' is not defined

# %%
type(maaax)
# Out:
# str

# %%
enumerate

# %%
import pandas as pd
df = pd.read_csv("https://goo.gl/iDUKrL")
song_list = list(df.reset_index().T.to_dict().values())
song_list
# Out:
# [{'index': 0,
#   '곡일련번호': 31346009,
#   '순위': 1,
#   '앨범': '삐삐',
#   '곡명': '삐삐',
#   '가수': '아이유',
#   '커버이미지_주소': 'https://cdnimg.melon.co.kr/cm/album/images/102/10/535/10210535_500.jpg/melon/resize/120/quality/80/optimize',
#   '좋아요': 61528},
#  {'index': 1,
#   '곡일련번호': 31344113,
#   '순위': 2,
#   '앨범': '시간이 들겠지',
#   '곡명': '시간이 들겠지 (Feat. Colde)',
#   '가수': '로꼬',
#   '커버이미지_주소': 'https://cdnimg.melon.co.kr/cm/album/images/102/10/198/10210198_500.jpg/melon/resize/120/quality/80/optimize',
#   '좋아요': 48331},
#  {'index': 2,
#   '곡일련번호': 31340985,
#   '순위': 3,
#   '앨범': '쇼미더머니 777 Episode 1',
#   '곡명': 'Good Day (Feat. 팔로알토) (Prod. 코드 쿤스트)',
#   '가수': 'pH-1',
#   '커버이미지_주소': 'https://cdnimg.melon.co.kr/cm/album/images/102/09/647/10209647_500.jpg/melon/resize/120/quality/80/optimize',
#   '좋아요': 54022},
#  {'index': 3,
#   '곡일련번호': 31316695,
#   '순위': 4,
#   '앨범': '하루도 그대를 사랑하지 않은 적이 없었다',
#   '곡명': '하루도 그대를 사랑하지 않은 적이 없었다',
#   '가수': '임창정',
# ...

# %%
for song in song_list:
 #   if '가을' in song['곡명']:
    if song['좋아요'] > 200_000 :
        line = '{곡명} {가수} {좋아요}'.format(**song)  # unpacking
        print(line)
# Out:
# FAKE LOVE 방탄소년단 253847
# Way Back Home 숀 (SHAUN) 225308
# 봄날 방탄소년단 359130
# DNA 방탄소년단 323911
# 에너제틱 (Energetic) Wanna One (워너원) 268394
# 사랑을 했다 (LOVE SCENARIO) iKON 267692
# Beautiful Wanna One (워너원) 216065
# 밤편지 아이유 283167
# 그날처럼 장덕철 208427
# 그리워하다 비투비 203463
# 선물 멜로망스 266869
