# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='Malgun Gothic')
rc('axes', unicode_minus=False)

# %%
import datetime
import os
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
MARKET_CODE_DICT = {
    'kospi': 'stockMkt',
    'kosdaq': 'kosdaqMkt',
    'konex': 'konexMkt'
}

# %%
DOWNLOAD_URL = 'kind.krx.co.kr/corpgeneral/corpList.do'

def download_stock_codes(market=None, delisted=False):
    params = {'method': 'download'}

    if market.lower() in MARKET_CODE_DICT:
        params['marketType'] = MARKET_CODE_DICT[market]

    if not delisted:
        params['searchType'] = 13

    params_string = urllib.parse.urlencode(params)
    request_url = urllib.parse.urlunsplit(['http', DOWNLOAD_URL, '', params_string, ''])

    df = pd.read_html(request_url, header=0)[0]
    df.종목코드 = df.종목코드.map('{:06d}'.format)

    return df

# %%
sto_code = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13')[0]
sto_code[:5]
# Out:
#      회사명   종목코드             업종  \
# 0  GS글로벌   1250      상품 종합 도매업
# 1  HSD엔진  82740  일반 목적용 기계 제조업
# 2  KG케미칼   1390    기초 화학물질 제조업
# 3  LG이노텍  11070       전자부품 제조업
# 4    OCI  10060    기초 화학물질 제조업
#
#                                                 주요제품         상장일  결산월  \
# 0  수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 1                                     대형선박용엔진,내연발전엔진  2011-01-04  12월
# 2                          콘크리트혼화제, 비료, 친환경농자재, 수처리제  1989-08-25  12월
# 3                                        기타 전자부품 제조업  2008-07-24  12월
# 4   타르제품,카본블랙,무수프탈산,농약원제,석탄화학제품,정밀화학제품,플라스틱창호재 제조,판매  1985-07-09  12월
#
#                          대표자명                         홈페이지     지역
# 0                         김태형       http://www.gsgcorp.com  서울특별시
# 1                         고영열  http://www.doosanengine.com   경상남도
# 2                         김경묵      http://www.kgchem.co.kr  울산광역시
# 3                         정철동   http://www.lginnotek.co.kr  서울특별시
# 4  백우석, 이우현, 김택중(3인, 각자 대표이사)         http://www.oci.co.kr  서울특별시

# %%
date_today = datetime.date.today()
date_key = date_today.strftime('%y%m%d')

# %%
code_list_save = ('data/code_list/' + 'code_list_' + date_key + '.csv').strip()
code_list_save
# Out:
# 'data/code_list/code_list_190729.csv'

# %%
sto_code.to_csv(code_list_save, encoding='euc-kr', index=False) #cp949
print('save >> ' + code_list_save)
# Out:
# save >> data/code_list/code_list_190729.csv

# %%
code_list_load = ('data/code_list/' + os.listdir('data/code_list')[-1])
code_list_load
# Out:
# 'data/code_list/code_list_190729.csv'

# %%
# os.path.getmtime('data/')

# %% [markdown]
# ### 저장 로드 방식 다시해~

# %%
sto_code = pd.read_csv(code_list_load, encoding='euc-kr')
sto_code[:3]
# Out:
#      회사명   종목코드             업종  \
# 0  GS글로벌   1250      상품 종합 도매업
# 1  HSD엔진  82740  일반 목적용 기계 제조업
# 2  KG케미칼   1390    기초 화학물질 제조업
#
#                                                 주요제품         상장일  결산월 대표자명  \
# 0  수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월  김태형
# 1                                     대형선박용엔진,내연발전엔진  2011-01-04  12월  고영열
# 2                          콘크리트혼화제, 비료, 친환경농자재, 수처리제  1989-08-25  12월  김경묵
#
#                           홈페이지     지역
# 0       http://www.gsgcorp.com  서울특별시
# 1  http://www.doosanengine.com   경상남도
# 2      http://www.kgchem.co.kr  울산광역시

# %%
sto_code['종목코드'] = sto_code['종목코드'].map('{:06d}'.format)

# %%
sto_code_sort = sto_code[['회사명', '종목코드']]
sto_code_sort[:5]
# Out:
#      회사명    종목코드
# 0  GS글로벌  001250
# 1  HSD엔진  082740
# 2  KG케미칼  001390
# 3  LG이노텍  011070
# 4    OCI  010060

# %%
def last_page_finder(html):
    page_pkg = html.find_all("table",align="center")
    last_page_pkg = page_pkg[0].find_all("td",class_="pgRR")[0].a.get('href')
    last_page_num = int(last_page_pkg.split("=")[-1].strip())
    return last_page_num

# %%
item_code = 'KOSPI' #page=1

# %%
sise_url = 'https://finance.naver.com/sise/sise_index_day.nhn?code=' + item_code

# %%
source_html = BeautifulSoup(urlopen(sise_url).read(), 'lxml') #html.parser

# %%
last_page = last_page_finder(source_html)

# %%
sise_df = pd.DataFrame()

# %%
for i in range(1, last_page+1):
    url = (f'{sise_url}&page={i}')
    sise_df = sise_df.append(pd.read_html(url, header=0)[0], ignore_index=True)

sise_df
# Out:
#                날짜      체결가    전일비     등락률   거래량(천주)   거래대금(백만)
# 0             NaN      NaN    NaN     NaN       NaN        NaN
# 1      2019.07.29  2029.48  36.78  -1.78%  608670.0  4681216.0
# 2      2019.07.26  2066.26   8.22  -0.40%  583332.0  5056450.0
# 3      2019.07.25  2074.48   7.82  -0.38%  590890.0  5126430.0
# 4             NaN      NaN    NaN     NaN       NaN        NaN
# 5             NaN      NaN    NaN     NaN       NaN        NaN
# 6             NaN      NaN    NaN     NaN       NaN        NaN
# 7             NaN      NaN    NaN     NaN       NaN        NaN
# 8      2019.07.24  2082.30  19.15  -0.91%  841580.0  4115461.0
# 9      2019.07.23  2101.45   8.11  +0.39%  640162.0  4523644.0
# 10     2019.07.22  2093.34   1.02  -0.05%  320412.0  3156360.0
# 11            NaN      NaN    NaN     NaN       NaN        NaN
# 12            NaN      NaN    NaN     NaN       NaN        NaN
# 13            NaN      NaN    NaN     NaN       NaN        NaN
# 14     2019.07.19  2094.36  27.81  +1.35%  386118.0  4037112.0
# 15     2019.07.18  2066.55   6.37  -0.31%  437178.0  3848957.0
# 16     2019.07.17  2072.92  18.95  -0.91%  752119.0  4549215.0
# 17            NaN      NaN    NaN     NaN       NaN        NaN
# 18            NaN      NaN    NaN     NaN       NaN        NaN
# 19            NaN      NaN    NaN     NaN       NaN        NaN
# 20            NaN      NaN    NaN     NaN       NaN        NaN
# 21     2019.07.16  2091.87   9.39  +0.45%  674500.0  5158374.0
# 22     2019.07.15  2082.48   4.18  -0.20%  455075.0  3656611.0
# 23     2019.07.12  2086.66   6.08  +0.29%  398353.0  3714594.0
# 24            NaN      NaN    NaN     NaN       NaN        NaN
# 25            NaN      NaN    NaN     NaN       NaN        NaN
# 26            NaN      NaN    NaN     NaN       NaN        NaN
# 27     2019.07.11  2080.58  21.80  +1.06%  368242.0  4934006.0
# 28     2019.07.10  2058.78   6.75  +0.33%  350018.0  3867014.0
# 29     2019.07.09  2052.03  12.14  -0.59%  433474.0  4361543.0
# ...           ...      ...    ...     ...       ...        ...
# 16701  1990.01.17   874.41   9.02  -1.02%    6927.0   141562.0
# 16702  1990.01.16   883.43   0.39  +0.04%   10384.0   216377.0
# 16703         NaN      NaN    NaN     NaN       NaN        NaN
# 16704         NaN      NaN    NaN     NaN       NaN        NaN
# 16705         NaN      NaN    NaN     NaN       NaN        NaN
# 16706  1990.01.15   883.04  10.43  -1.17%    8854.0   184112.0
# 16707  1990.01.13   893.47   9.64  -1.07%    7384.0   156742.0
# 16708  1990.01.12   903.11   0.16  -0.02%   11627.0   250693.0
# 16709         NaN      NaN    NaN     NaN       NaN        NaN
# 16710         NaN      NaN    NaN     NaN       NaN        NaN
# 16711         NaN      NaN    NaN     NaN       NaN        NaN
# 16712         NaN      NaN    NaN     NaN       NaN        NaN
# 16713  1990.01.11   903.27   8.21  -0.90%   12647.0   274573.0
# 16714  1990.01.10   911.48   8.73  -0.95%   15278.0   322830.0
# 16715  1990.01.09   920.21   0.75  +0.08%   18646.0   382992.0
# 16716         NaN      NaN    NaN     NaN       NaN        NaN
# 16717         NaN      NaN    NaN     NaN       NaN        NaN
# 16718         NaN      NaN    NaN     NaN       NaN        NaN
# 16719  1990.01.08   919.46   6.60  +0.72%   17577.0   369946.0
# 16720  1990.01.06   912.86   2.25  -0.25%   12519.0   269397.0
# 16721  1990.01.05   915.11  13.71  -1.48%   22179.0   476295.0
# 16722         NaN      NaN    NaN     NaN       NaN        NaN
# 16723         NaN      NaN    NaN     NaN       NaN        NaN
# 16724         NaN      NaN    NaN     NaN       NaN        NaN
# 16725         NaN      NaN    NaN     NaN       NaN        NaN
# 16726  1990.01.04   928.82  20.23  +2.23%   18094.0   405061.0
# 16727         NaN      NaN    NaN     NaN       NaN        NaN
# 16728         NaN      NaN    NaN     NaN       NaN        NaN
# 16729         NaN      NaN    NaN     NaN       NaN        NaN
# 16730         NaN      NaN    NaN     NaN       NaN        NaN
#
# [16731 rows x 6 columns]

# %%
sise_df = sise_df.dropna(axis=0)
sise_df[-5:]
# Out:
#                날짜     체결가    전일비     등락률  거래량(천주)  거래대금(백만)
# 16715  1990.01.09  920.21   0.75  +0.08%  18646.0  382992.0
# 16719  1990.01.08  919.46   6.60  +0.72%  17577.0  369946.0
# 16720  1990.01.06  912.86   2.25  -0.25%  12519.0  269397.0
# 16721  1990.01.05  915.11  13.71  -1.48%  22179.0  476295.0
# 16726  1990.01.04  928.82  20.23  +2.23%  18094.0  405061.0

# %%
type(sise_df['체결가'].values[0])
# Out:
# numpy.float64

# %%
sise_df['날짜'] = pd.to_datetime(sise_df['날짜'])
# Out:
# C:\Anaconda3\envs\DT_Academy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sise_df['등락률'] = sise_df['등락률'].map(lambda x: float(x.split("%")[0].strip()))
# Out:
# C:\Anaconda3\envs\DT_Academy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sise_df.dtypes
# Out:
# 날짜          datetime64[ns]
# 체결가                float64
# 전일비                float64
# 등락률                float64
# 거래량(천주)            float64
# 거래대금(백만)           float64
# dtype: object

# %%
sise_df[-5:]
# Out:
#               날짜     체결가    전일비   등락률  거래량(천주)  거래대금(백만)
# 16715 1990-01-09  920.21   0.75  0.08  18646.0  382992.0
# 16719 1990-01-08  919.46   6.60  0.72  17577.0  369946.0
# 16720 1990-01-06  912.86   2.25 -0.25  12519.0  269397.0
# 16721 1990-01-05  915.11  13.71 -1.48  22179.0  476295.0
# 16726 1990-01-04  928.82  20.23  2.23  18094.0  405061.0

# %%
sise_save = 'data/sise_list/' + item_code + '_' + date_key + '.csv'
sise_save
# Out:
# 'data/sise_list/KOSPI_190729.csv'

# %%
sise_df.to_csv(sise_save, encoding='euc-kr', index=False) #cp949
print('save >> ' + sise_save)
# Out:
# save >> data/sise_list/KOSPI_190729.csv
